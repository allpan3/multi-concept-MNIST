# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from main import get_train_test_dls

# %%
train_dl, test_dl, vsa = get_train_test_dls()

# %%
import matplotlib.pyplot as plt

# %%
for images, labels, targets in train_dl:
    plt.imshow(images[0])
    print(labels[0])
    break
# Out:
# [{'pos_x': 2, 'pos_y': 0, 'color': 3, 'digit': 5}, {'pos_x': 1, 'pos_y': 0, 'color': 3, 'digit': 6}]
